# %%
from typing import TypedDict, Annotated, Optional
from langgraph.graph import add_messages, StateGraph, END
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_tavily import TavilySearch
from langgraph.checkpoint.memory import MemorySaver
from uuid import uuid4
import json


load_dotenv()

model = ChatGroq(model="llama-3.3-70b-versatile")

response = model.predict("Hello. How can I help you today?")
print(response)
# Out:
# C:\Users\Daksh\AppData\Local\Temp\ipykernel_90348\1248837982.py:15: LangChainDeprecationWarning: The method `BaseChatModel.predict` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = model.predict("Hello. How can I help you today?")
# Hello. I'm an AI, so I don't need help, but I'm here to assist you with any questions or topics you'd like to discuss. How's your day going so far? Is there something on your mind that you'd like to talk about or learn more about? I'm all ears (or rather, all text).

# %%
search_tool = TavilySearch(max_results=2)

response = search_tool.invoke("What is kind of crop can i plant in my garden? in bhind")
response

# %%
tools = [search_tool]

memory = MemorySaver()

llm_with_tools = model.bind_tools(tools=tools)

# %%
response = llm_with_tools.invoke("What is weather in bhind?")
response
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'nr45n9e9v', 'function': {'arguments': '{"query":"Bhind weather","topic":"general"}', 'name': 'tavily_search'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1793, 'total_tokens': 1817, 'completion_time': 0.070578797, 'prompt_time': 0.149548471, 'queue_time': 0.099632758, 'total_time': 0.220127268}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_2ddfbb0da0', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--95d159b6-526b-4802-a91e-c910ba141727-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Bhind weather', 'topic': 'general'}, 'id': 'nr45n9e9v', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1793, 'output_tokens': 24, 'total_tokens': 1817})

# %%
dict(response)
# Out:
# {'content': '',
#  'additional_kwargs': {'tool_calls': [{'id': 'nr45n9e9v',
#     'function': {'arguments': '{"query":"Bhind weather","topic":"general"}',
#      'name': 'tavily_search'},
#     'type': 'function'}]},
#  'response_metadata': {'token_usage': {'completion_tokens': 24,
#    'prompt_tokens': 1793,
#    'total_tokens': 1817,
#    'completion_time': 0.070578797,
#    'prompt_time': 0.149548471,
#    'queue_time': 0.099632758,
#    'total_time': 0.220127268},
#   'model_name': 'llama-3.3-70b-versatile',
#   'system_fingerprint': 'fp_2ddfbb0da0',
#   'service_tier': 'on_demand',
#   'finish_reason': 'tool_calls',
#   'logprobs': None},
#  'type': 'ai',
#  'name': None,
#  'id': 'run--95d159b6-526b-4802-a91e-c910ba141727-0',
#  'example': False,
#  'tool_calls': [{'name': 'tavily_search',
#    'args': {'query': 'Bhind weather', 'topic': 'general'},
#    'id': 'nr45n9e9v',
#    'type': 'tool_call'}],
#  'invalid_tool_calls': [],
#  'usage_metadata': {'input_tokens': 1793,
#   'output_tokens': 24,
#   'total_tokens': 1817}}

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from langchain.agents import ToolExecutor
#       2 from langchain_core.messages import AIMessage
#       4 # Create tool executor from your tools
#
# ImportError: cannot import name 'ToolExecutor' from 'langchain.agents' (e:\Agent-AI\.venv\lib\site-packages\langchain\agents\__init__.py)
